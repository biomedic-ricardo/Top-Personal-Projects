# %%
# !pip install kmodes
# !pip install geoplotlib
# !pip install ipyleaflet

# !jupyter nbextension enable --py --sys-prefix ipyleaflet
# %pylab inline
# %matplotlib inline


import pandas as pd #
import time
import os
import numpy as np #
import matplotlib.pyplot as plt # plotting library for Python
import seaborn as sns
import matplotlib.cm
import matplotlib.colors as colors

from kmodes.kprototypes import KPrototypes
from pandas import DataFrame
from pandas import set_option
from numpy import mean, std
from pandas.plotting import scatter_matrix
from sklearn.cluster import KMeans
from sklearn.preprocessing import scale
from matplotlib.colors import Normalize

from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
from numpy import random, float
sns.set_style("darkgrid")
# Out:
# Requirement already satisfied: kmodes in c:\users\usuario\anaconda3\lib\site-packages (0.10.2)
# Requirement already satisfied: scikit-learn>=0.19.0 in c:\users\usuario\anaconda3\lib\site-packages (from kmodes) (0.23.2)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\usuario\anaconda3\lib\site-packages (from kmodes) (1.19.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\usuario\anaconda3\lib\site-packages (from kmodes) (0.17.0)
# Requirement already satisfied: scipy>=0.13.3 in c:\users\usuario\anaconda3\lib\site-packages (from kmodes) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\usuario\anaconda3\lib\site-packages (from scikit-learn>=0.19.0->kmodes) (2.1.0)
# Requirement already satisfied: geoplotlib in c:\users\usuario\anaconda3\lib\site-packages (0.3.2)
# Requirement already satisfied: ipyleaflet in c:\users\usuario\anaconda3\lib\site-packages (0.13.3)
# Requirement already satisfied: ipywidgets<8,>=7.5.0 in c:\users\usuario\anaconda3\lib\site-packages (from ipyleaflet) (7.5.1)
# Requirement already satisfied: branca<0.5,>=0.3.1 in c:\users\usuario\anaconda3\lib\site-packages (from ipyleaflet) (0.4.1)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\usuario\anaconda3\lib\site-packages (from ipyleaflet) (0.2.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\usuario\anaconda3\lib\site-packages (from ipywidgets<8,>=7.5.0->ipyleaflet) (5.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\usuario\anaconda3\lib\site-packages (from ipywidgets<8,>=7.5.0->ipyleaflet) (5.3.4)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\usuario\anaconda3\lib\site-packages (from ipywidgets<8,>=7.5.0->ipyleaflet) (5.0.8)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\usuario\anaconda3\lib\site-packages (from ipywidgets<8,>=7.5.0->ipyleaflet) (3.5.1)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in c:\users\usuario\anaconda3\lib\site-packages (from ipywidgets<8,>=7.5.0->ipyleaflet) (7.19.0)
# Requirement already satisfied: jinja2 in c:\users\usuario\anaconda3\lib\site-packages (from branca<0.5,>=0.3.1->ipyleaflet) (2.11.2)
# Requirement already satisfied: ipython-genutils in c:\users\usuario\anaconda3\lib\site-packages (from traitlets>=4.3.1->ipywidgets<8,>=7.5.0->ipyleaflet) (0.2.0)
# Requirement already satisfied: jupyter-client in c:\users\usuario\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.5.0->ipyleaflet) (6.1.7)
# Requirement already satisfied: tornado>=4.2 in c:\users\usuario\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.5.0->ipyleaflet) (6.0.4)
# Requirement already satisfied: jupyter-core in c:\users\usuario\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet) (4.6.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\usuario\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet) (3.2.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\usuario\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (6.1.4)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\usuario\appdata\roaming\python\python38\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (0.4.3)
# Requirement already satisfied: pygments in c:\users\usuario\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (2.7.2)
# Requirement already satisfied: backcall in c:\users\usuario\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\usuario\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (50.3.1.post20201107)
# Requirement already satisfied: decorator in c:\users\usuario\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (4.4.2)
# Requirement already satisfied: pickleshare in c:\users\usuario\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\usuario\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (3.0.8)
# Requirement already satisfied: jedi>=0.10 in c:\users\usuario\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (0.17.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\usuario\anaconda3\lib\site-packages (from jinja2->branca<0.5,>=0.3.1->ipyleaflet) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\usuario\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets<8,>=7.5.0->ipyleaflet) (2.8.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\usuario\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets<8,>=7.5.0->ipyleaflet) (19.0.2)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\usuario\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet) (227)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\usuario\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet) (20.3.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\usuario\appdata\roaming\python\python38\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet) (1.15.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\usuario\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.17.3)
# Requirement already satisfied: prometheus-client in c:\users\usuario\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.8.0)
# Requirement already satisfied: nbconvert in c:\users\usuario\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (6.0.7)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\usuario\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.9.1)
# Requirement already satisfied: Send2Trash in c:\users\usuario\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (1.5.0)
# Requirement already satisfied: argon2-cffi in c:\users\usuario\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (20.1.0)
# Requirement already satisfied: wcwidth in c:\users\usuario\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\usuario\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets<8,>=7.5.0->ipyleaflet) (0.7.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\usuario\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\usuario\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\usuario\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (1.4.3)
# Requirement already satisfied: defusedxml in c:\users\usuario\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\usuario\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.8.4)
# Requirement already satisfied: bleach in c:\users\usuario\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (3.2.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\usuario\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.5.1)
# Requirement already satisfied: testpath in c:\users\usuario\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.4.4)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\usuario\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\usuario\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (1.14.3)
# Requirement already satisfied: webencodings in c:\users\usuario\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (0.5.1)
# Requirement already satisfied: packaging in c:\users\usuario\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (20.4)
# Requirement already satisfied: nest-asyncio in c:\users\usuario\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (1.4.2)
# Requirement already satisfied: async-generator in c:\users\usuario\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (1.10)
# Requirement already satisfied: pycparser in c:\users\usuario\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (2.20)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\usuario\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->ipyleaflet) (2.4.7)
# Populating the interactive namespace from numpy and matplotlib
# Enabling notebook extension jupyter-leaflet/extension...
#       - Validating: ok

# %%
brewing_df = pd.read_csv (r'C:\Users\usuario\Documents\Hackathon\DATASET_HACKATHON.csv')   
#read the csv file (put 'r' before the path string to address any special characters in the path, such as '\'). Don't forget to put the file name at the end of the path + ".csv"

# %%
print (brewing_df)
# Out:
#       Id_Cliente id_Agencia  Frecuencia  Vol_Entrega        lat        lon
# 0              1         A1           1          2.0  20.506052 -98.212377
# 1              2         A1           1         17.0  20.458128 -98.221248
# 2              3         A1           1          2.0  20.530427 -98.236860
# 3              4         A1           3         15.0  20.488655 -98.202940
# 4              5         A1           1          2.0  20.533253 -98.219669
# ...          ...        ...         ...          ...        ...        ...
# 3620        3621         A1           1         15.0  20.558651 -98.149706
# 3621        3622         A1           1          2.0  20.541300 -98.157300
# 3622        3623         A1           1          6.0  20.509200 -98.128000
# 3623        3624         A1           1         31.0  20.513400 -98.154500
# 3624        3625         A1           2         18.5  20.521772 -98.166209
#
# [3625 rows x 6 columns]

# %%
brewing_df = brewing_df.drop(["id_Agencia"],axis=1)

# %%
brewing_df
# Out:
#       Id_Cliente  Frecuencia  Vol_Entrega        lat        lon
# 0              1           1          2.0  20.506052 -98.212377
# 1              2           1         17.0  20.458128 -98.221248
# 2              3           1          2.0  20.530427 -98.236860
# 3              4           3         15.0  20.488655 -98.202940
# 4              5           1          2.0  20.533253 -98.219669
# ...          ...         ...          ...        ...        ...
# 3620        3621           1         15.0  20.558651 -98.149706
# 3621        3622           1          2.0  20.541300 -98.157300
# 3622        3623           1          6.0  20.509200 -98.128000
# 3623        3624           1         31.0  20.513400 -98.154500
# 3624        3625           2         18.5  20.521772 -98.166209
#
# [3625 rows x 5 columns]

# %%
brewing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3625 entries, 0 to 3624
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id_Cliente   3625 non-null   int64
#  1   Frecuencia   3625 non-null   int64
#  2   Vol_Entrega  3625 non-null   float64
#  3   lat          3625 non-null   float64
#  4   lon          3625 non-null   float64
# dtypes: float64(3), int64(2)
# memory usage: 141.7 KB

# %%
brewing_df.describe()
# Out:
#         Id_Cliente   Frecuencia  Vol_Entrega          lat          lon
# count  3625.000000  3625.000000  3625.000000  3625.000000  3625.000000
# mean   1813.000000     1.097103    13.195724    20.508669   -98.189818
# std    1046.591691     0.319449    20.158246     0.034647     0.044283
# min       1.000000     1.000000     0.000000    20.435038   -98.298948
# 25%     907.000000     1.000000     2.000000    20.480661   -98.221491
# 50%    1813.000000     1.000000     6.000000    20.507537   -98.183900
# 75%    2719.000000     1.000000    15.000000    20.537206   -98.153300
# max    3625.000000     3.000000   175.000000    20.608307   -98.108122

# %%
for i,row in brewing_df.iterrows():
    brewing_df.loc[i,'Total_Entrega']=row['Frecuencia']*row['Vol_Entrega']

# %%
brewing_df_con_Vol_total = brewing_df

# %%
brewing_df_con_Vol_total = brewing_df.drop(["Frecuencia","Vol_Entrega"],axis=1)

# %%
brewing_df_con_Vol_total #only to show if we are doing the things rigth
# Out:
#       Id_Cliente        lat        lon  Total_Entrega
# 0              1  20.506052 -98.212377            2.0
# 1              2  20.458128 -98.221248           17.0
# 2              3  20.530427 -98.236860            2.0
# 3              4  20.488655 -98.202940           45.0
# 4              5  20.533253 -98.219669            2.0
# ...          ...        ...        ...            ...
# 3620        3621  20.558651 -98.149706           15.0
# 3621        3622  20.541300 -98.157300            2.0
# 3622        3623  20.509200 -98.128000            6.0
# 3623        3624  20.513400 -98.154500           31.0
# 3624        3625  20.521772 -98.166209           37.0
#
# [3625 rows x 4 columns]

# %%
#normalize the data
newdf = DataFrame(scale(brewing_df_con_Vol_total), index=brewing_df_con_Vol_total.index, columns=brewing_df_con_Vol_total.columns)

# %%
newdf
# Out:
#       Id_Cliente       lat       lon  Total_Entrega
# 0      -1.731573 -0.075534 -0.509502      -0.566267
# 1      -1.730617 -1.458921 -0.709853       0.086772
# 2      -1.729662  0.628081 -1.062449      -0.566267
# 3      -1.728706 -0.577721 -0.296368       1.305777
# 4      -1.727751  0.709657 -0.674192      -0.566267
# ...          ...       ...       ...            ...
# 3620    1.727751  1.442802  0.905917      -0.000300
# 3621    1.728706  0.941944  0.734407      -0.566267
# 3622    1.729662  0.015337  1.396146      -0.392123
# 3623    1.730617  0.136575  0.797645       0.696274
# 3624    1.731573  0.378243  0.533198       0.957490
#
# [3625 rows x 4 columns]

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3625 entries, 0 to 3624
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id_Cliente     3625 non-null   float64
#  1   lat            3625 non-null   float64
#  2   lon            3625 non-null   float64
#  3   Total_Entrega  3625 non-null   float64
# dtypes: float64(4)
# memory usage: 113.4 KB

# %%
newdf.describe()
# Out:
#          Id_Cliente           lat           lon  Total_Entrega
# count  3.625000e+03  3.625000e+03  3.625000e+03   3.625000e+03
# mean   6.376509e-17  5.013277e-14  6.135261e-14   2.216771e-15
# std    1.000138e+00  1.000138e+00  1.000138e+00   1.000138e+00
# min   -1.731573e+00 -2.125443e+00 -2.464702e+00  -6.533387e-01
# 25%   -8.657865e-01 -8.084775e-01 -7.153414e-01  -5.662669e-01
# 50%    0.000000e+00 -3.266783e-02  1.336485e-01  -3.921233e-01
# 75%    8.657865e-01  8.237654e-01  8.247472e-01   1.303074e-01
# max    1.731573e+00  2.876186e+00  1.845089e+00   6.965444e+00

# %%
kproto = KPrototypes(n_clusters=6, init='Huang', verbose=2, random_state=42,max_iter=20, n_init=100,n_jobs=-2,gamma=.25)
clusters = kproto.fit_predict(newdf, categorical=[0])
# Out:
# Best run was number 57

# %% [markdown]
# n_jobs: The number of jobs to use for the computation. This works by computing
#         each of the n_init runs in parallel.
#         If -1 all CPUs are used. If 1 is given, no parallel computing code is
#         used at all, which is useful for debugging. For n_jobs below -1,
#         (n_cpus + 1 + n_jobs) are used. Thus for n_jobs = -2, all CPUs but one
#         are used.

# %%
print(kproto.cluster_centroids_)
# Out:
# [array([[-0.90940003,  0.5179821 , -0.29555836],
#        [ 0.60370625, -0.47073194, -0.2966836 ],
#        [-0.31403557,  0.18156368,  1.64550684],
#        [-0.82722818, -1.47497914, -0.15331613],
#        [-0.18695303, -0.08607865,  4.54845053],
#        [ 1.03779344,  0.92957255, -0.30486726]]), array([[-1.72106131],
#        [-1.72775061],
#        [-1.72870622],
#        [-1.73061745],
#        [-1.70290464],
#        [-1.72583938]])]

# %%
cluster_dict=[]
for c in clusters:
    cluster_dict.append(c)

# %%
cluster_dict
plt.plot(cluster_dict)

# %%
newdf['cluster']=cluster_dict

# %%
newdf
# Out:
#       Id_Cliente       lat       lon  Total_Entrega  cluster
# 0      -1.731573 -0.075534 -0.509502      -0.566267        1
# 1      -1.730617 -1.458921 -0.709853       0.086772        3
# 2      -1.729662  0.628081 -1.062449      -0.566267        1
# 3      -1.728706 -0.577721 -0.296368       1.305777        2
# 4      -1.727751  0.709657 -0.674192      -0.566267        1
# ...          ...       ...       ...            ...      ...
# 3620    1.727751  1.442802  0.905917      -0.000300        5
# 3621    1.728706  0.941944  0.734407      -0.566267        5
# 3622    1.729662  0.015337  1.396146      -0.392123        5
# 3623    1.730617  0.136575  0.797645       0.696274        2
# 3624    1.731573  0.378243  0.533198       0.957490        2
#
# [3625 rows x 5 columns]

# %%
newdf.to_csv(r'C:\Users\usuario\Documents\Hackathon\newdf.csv')

# %%
kproto = KPrototypes(n_clusters=6, verbose=2,max_iter=20)
clusters = kproto.fit_predict(newdf, categorical=[1])
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/20, moves: 847, ncost: 136799073.42418253
# Run: 1, iteration: 2/20, moves: 431, ncost: 121036262.59491411
# Run: 1, iteration: 3/20, moves: 282, ncost: 114834133.02604543
# Run: 1, iteration: 4/20, moves: 181, ncost: 112519850.25122233
# Run: 1, iteration: 5/20, moves: 93, ncost: 111910571.12603341
# Run: 1, iteration: 6/20, moves: 45, ncost: 111756567.67951836
# Run: 1, iteration: 7/20, moves: 24, ncost: 111713784.53936628
# Run: 1, iteration: 8/20, moves: 11, ncost: 111698992.6157876
# Run: 1, iteration: 9/20, moves: 6, ncost: 111693332.94435768
# Run: 1, iteration: 10/20, moves: 4, ncost: 111689153.56122312
# Run: 1, iteration: 11/20, moves: 3, ncost: 111686755.71072079
# Run: 1, iteration: 12/20, moves: 3, ncost: 111684910.42633045
# Run: 1, iteration: 13/20, moves: 4, ncost: 111682756.28429864
# Run: 1, iteration: 14/20, moves: 1, ncost: 111682184.45955694
# Run: 1, iteration: 15/20, moves: 3, ncost: 111681033.6980131
# Run: 1, iteration: 16/20, moves: 3, ncost: 111679832.64628908
# Run: 1, iteration: 17/20, moves: 0, ncost: 111679832.64628908
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/20, moves: 824, ncost: 149735878.76876813
# Run: 2, iteration: 2/20, moves: 542, ncost: 124575322.53003307
# Run: 2, iteration: 3/20, moves: 336, ncost: 115884818.11991973
# Run: 2, iteration: 4/20, moves: 167, ncost: 113180748.32732022
# Run: 2, iteration: 5/20, moves: 81, ncost: 112328321.25470513
# Run: 2, iteration: 6/20, moves: 40, ncost: 112014556.27883856
# Run: 2, iteration: 7/20, moves: 22, ncost: 111878222.58511415
# Run: 2, iteration: 8/20, moves: 16, ncost: 111810149.90998426
# Run: 2, iteration: 9/20, moves: 13, ncost: 111768562.28774688
# Run: 2, iteration: 10/20, moves: 11, ncost: 111743656.42081073
# Run: 2, iteration: 11/20, moves: 9, ncost: 111727913.99416265
# Run: 2, iteration: 12/20, moves: 8, ncost: 111717555.91458443
# Run: 2, iteration: 13/20, moves: 6, ncost: 111709550.0880544
# Run: 2, iteration: 14/20, moves: 6, ncost: 111703158.15726322
# Run: 2, iteration: 15/20, moves: 6, ncost: 111697638.7997058
# Run: 2, iteration: 16/20, moves: 4, ncost: 111694369.89602546
# Run: 2, iteration: 17/20, moves: 3, ncost: 111692037.85375644
# Run: 2, iteration: 18/20, moves: 5, ncost: 111688615.1908837
# Run: 2, iteration: 19/20, moves: 2, ncost: 111687318.72512545
# Run: 2, iteration: 20/20, moves: 5, ncost: 111684867.43531033
# Run: 2, iteration: 21/20, moves: 3, ncost: 111683329.9962114
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/20, moves: 518, ncost: 123559652.64126365
# Run: 3, iteration: 2/20, moves: 249, ncost: 116623831.17027149
# Run: 3, iteration: 3/20, moves: 147, ncost: 113996968.50378644
# Run: 3, iteration: 4/20, moves: 74, ncost: 112949448.34334771
# Run: 3, iteration: 5/20, moves: 41, ncost: 112475437.20373702
# Run: 3, iteration: 6/20, moves: 30, ncost: 112219787.21372487
# Run: 3, iteration: 7/20, moves: 24, ncost: 112075421.31965554
# Run: 3, iteration: 8/20, moves: 21, ncost: 111983992.29339562
# Run: 3, iteration: 9/20, moves: 19, ncost: 111915320.13219248
# Run: 3, iteration: 10/20, moves: 15, ncost: 111869624.62731539
# Run: 3, iteration: 11/20, moves: 13, ncost: 111835910.20478061
# Run: 3, iteration: 12/20, moves: 12, ncost: 111808917.96394111
# Run: 3, iteration: 13/20, moves: 11, ncost: 111786448.68035065
# Run: 3, iteration: 14/20, moves: 11, ncost: 111766296.27028227
# Run: 3, iteration: 15/20, moves: 10, ncost: 111749603.33857991
# Run: 3, iteration: 16/20, moves: 7, ncost: 111739408.82747044
# Run: 3, iteration: 17/20, moves: 7, ncost: 111729315.63489595
# Run: 3, iteration: 18/20, moves: 7, ncost: 111720117.89324172
# Run: 3, iteration: 19/20, moves: 7, ncost: 111712458.24975537
# Run: 3, iteration: 20/20, moves: 6, ncost: 111706585.49892996
# Run: 3, iteration: 21/20, moves: 5, ncost: 111701497.5244641
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/20, moves: 721, ncost: 137102037.25106466
# Run: 4, iteration: 2/20, moves: 493, ncost: 119619181.72071026
# Run: 4, iteration: 3/20, moves: 264, ncost: 114357294.98317146
# Run: 4, iteration: 4/20, moves: 135, ncost: 112672991.57452628
# Run: 4, iteration: 5/20, moves: 66, ncost: 112111199.69975492
# Run: 4, iteration: 6/20, moves: 35, ncost: 111905691.89353211
# Run: 4, iteration: 7/20, moves: 17, ncost: 111818159.15113468
# Run: 4, iteration: 8/20, moves: 13, ncost: 111770441.36815025
# Run: 4, iteration: 9/20, moves: 10, ncost: 111744654.85358132
# Run: 4, iteration: 10/20, moves: 9, ncost: 111728141.64756429
# Run: 4, iteration: 11/20, moves: 9, ncost: 111714092.698999
# Run: 4, iteration: 12/20, moves: 6, ncost: 111706415.75284034
# Run: 4, iteration: 13/20, moves: 4, ncost: 111701845.58988866
# Run: 4, iteration: 14/20, moves: 5, ncost: 111697638.7997058
# Run: 4, iteration: 15/20, moves: 4, ncost: 111694369.89602546
# Run: 4, iteration: 16/20, moves: 3, ncost: 111692037.85375644
# Run: 4, iteration: 17/20, moves: 5, ncost: 111688615.1908837
# Run: 4, iteration: 18/20, moves: 2, ncost: 111687318.72512545
# Run: 4, iteration: 19/20, moves: 5, ncost: 111684867.43531033
# Run: 4, iteration: 20/20, moves: 3, ncost: 111683329.9962114
# Run: 4, iteration: 21/20, moves: 5, ncost: 111681313.77606714
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/20, moves: 489, ncost: 145967495.06291762
# Run: 5, iteration: 2/20, moves: 241, ncost: 139127227.0365863
# Run: 5, iteration: 3/20, moves: 154, ncost: 134230500.04718208
# Run: 5, iteration: 4/20, moves: 131, ncost: 130440529.2009593
# Run: 5, iteration: 5/20, moves: 120, ncost: 127437017.11566712
# Run: 5, iteration: 6/20, moves: 113, ncost: 124923865.83014147
# Run: 5, iteration: 7/20, moves: 105, ncost: 122821790.156113
# Run: 5, iteration: 8/20, moves: 97, ncost: 121057967.97961509
# Run: 5, iteration: 9/20, moves: 88, ncost: 119585911.41606656
# Run: 5, iteration: 10/20, moves: 80, ncost: 118359491.74387455
# Run: 5, iteration: 11/20, moves: 77, ncost: 117273286.16593915
# Run: 5, iteration: 12/20, moves: 69, ncost: 116382794.73469801
# Run: 5, iteration: 13/20, moves: 66, ncost: 115601397.72363238
# Run: 5, iteration: 14/20, moves: 60, ncost: 114951802.54719847
# Run: 5, iteration: 15/20, moves: 54, ncost: 114417016.6258138
# Run: 5, iteration: 16/20, moves: 50, ncost: 113967806.03340991
# Run: 5, iteration: 17/20, moves: 46, ncost: 113588970.80064951
# Run: 5, iteration: 18/20, moves: 40, ncost: 113287788.1876248
# Run: 5, iteration: 19/20, moves: 38, ncost: 113024398.5314003
# Run: 5, iteration: 20/20, moves: 34, ncost: 112809079.51270185
# Run: 5, iteration: 21/20, moves: 33, ncost: 112615868.83542976
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/20, moves: 568, ncost: 132602326.74001618
# Run: 6, iteration: 2/20, moves: 207, ncost: 127898377.64627124
# Run: 6, iteration: 3/20, moves: 130, ncost: 124817864.9285483
# Run: 6, iteration: 4/20, moves: 112, ncost: 122537939.66521771
# Run: 6, iteration: 5/20, moves: 97, ncost: 120769802.70308957
# Run: 6, iteration: 6/20, moves: 87, ncost: 119330407.4345862
# Run: 6, iteration: 7/20, moves: 81, ncost: 118110576.30389771
# Run: 6, iteration: 8/20, moves: 74, ncost: 117089032.80329823
# Run: 6, iteration: 9/20, moves: 68, ncost: 116230706.472542
# Run: 6, iteration: 10/20, moves: 62, ncost: 115509278.99176621
# Run: 6, iteration: 11/20, moves: 59, ncost: 114884794.68983018
# Run: 6, iteration: 12/20, moves: 53, ncost: 114370196.58879748
# Run: 6, iteration: 13/20, moves: 50, ncost: 113923059.27047545
# Run: 6, iteration: 14/20, moves: 45, ncost: 113557138.17260598
# Run: 6, iteration: 15/20, moves: 41, ncost: 113248547.03779027
# Run: 6, iteration: 16/20, moves: 39, ncost: 112980338.01664193
# Run: 6, iteration: 17/20, moves: 34, ncost: 112769005.78688955
# Run: 6, iteration: 18/20, moves: 29, ncost: 112602327.06900896
# Run: 6, iteration: 19/20, moves: 30, ncost: 112446034.10090064
# Run: 6, iteration: 20/20, moves: 26, ncost: 112321492.50007716
# Run: 6, iteration: 21/20, moves: 25, ncost: 112211901.91539772
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/20, moves: 243, ncost: 119388097.56062225
# Run: 7, iteration: 2/20, moves: 91, ncost: 117942382.3976034
# Run: 7, iteration: 3/20, moves: 77, ncost: 116903005.86315963
# Run: 7, iteration: 4/20, moves: 68, ncost: 116063653.83666168
# Run: 7, iteration: 5/20, moves: 63, ncost: 115343031.60241269
# Run: 7, iteration: 6/20, moves: 58, ncost: 114742077.45109187
# Run: 7, iteration: 7/20, moves: 53, ncost: 114233998.82832178
# Run: 7, iteration: 8/20, moves: 48, ncost: 113814415.53878376
# Run: 7, iteration: 9/20, moves: 45, ncost: 113456760.29501216
# Run: 7, iteration: 10/20, moves: 41, ncost: 113157427.51301956
# Run: 7, iteration: 11/20, moves: 37, ncost: 112908266.66434135
# Run: 7, iteration: 12/20, moves: 35, ncost: 112699688.05008066
# Run: 7, iteration: 13/20, moves: 30, ncost: 112534199.19842924
# Run: 7, iteration: 14/20, moves: 28, ncost: 112390262.46731786
# Run: 7, iteration: 15/20, moves: 26, ncost: 112270545.33805743
# Run: 7, iteration: 16/20, moves: 22, ncost: 112179030.75374794
# Run: 7, iteration: 17/20, moves: 22, ncost: 112094550.8590809
# Run: 7, iteration: 18/20, moves: 19, ncost: 112026552.11076596
# Run: 7, iteration: 19/20, moves: 19, ncost: 111964477.98079714
# Run: 7, iteration: 20/20, moves: 16, ncost: 111917497.38596457
# Run: 7, iteration: 21/20, moves: 14, ncost: 111879851.46010059
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/20, moves: 695, ncost: 199600440.0451718
# Run: 8, iteration: 2/20, moves: 422, ncost: 173456063.52939576
# Run: 8, iteration: 3/20, moves: 225, ncost: 157090432.16611722
# Run: 8, iteration: 4/20, moves: 199, ncost: 146142380.55467618
# Run: 8, iteration: 5/20, moves: 176, ncost: 138528598.91858777
# Run: 8, iteration: 6/20, moves: 158, ncost: 132964728.10620177
# Run: 8, iteration: 7/20, moves: 142, ncost: 128764308.52953988
# Run: 8, iteration: 8/20, moves: 124, ncost: 125620589.64080068
# Run: 8, iteration: 9/20, moves: 114, ncost: 123106221.73126884
# Run: 8, iteration: 10/20, moves: 103, ncost: 121096487.50681695
# Run: 8, iteration: 11/20, moves: 92, ncost: 119479386.43267119
# Run: 8, iteration: 12/20, moves: 85, ncost: 118140495.68009332
# Run: 8, iteration: 13/20, moves: 78, ncost: 117026016.973604
# Run: 8, iteration: 14/20, moves: 71, ncost: 116107852.747642
# Run: 8, iteration: 15/20, moves: 64, ncost: 115358652.62993063
# Run: 8, iteration: 16/20, moves: 58, ncost: 114741993.794938
# Run: 8, iteration: 17/20, moves: 52, ncost: 114236610.55674891
# Run: 8, iteration: 18/20, moves: 49, ncost: 113807448.94069992
# Run: 8, iteration: 19/20, moves: 41, ncost: 113478889.68016264
# Run: 8, iteration: 20/20, moves: 41, ncost: 113177505.04058662
# Run: 8, iteration: 21/20, moves: 37, ncost: 112926403.19536792
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/20, moves: 1271, ncost: 226615668.35159343
# Run: 9, iteration: 2/20, moves: 740, ncost: 165244448.06709346
# Run: 9, iteration: 3/20, moves: 485, ncost: 142689153.42416176
# Run: 9, iteration: 4/20, moves: 392, ncost: 130738152.25232194
# Run: 9, iteration: 5/20, moves: 344, ncost: 123145692.02067146
# Run: 9, iteration: 6/20, moves: 282, ncost: 118351661.08907688
# Run: 9, iteration: 7/20, moves: 218, ncost: 115500945.83658856
# Run: 9, iteration: 8/20, moves: 160, ncost: 113905847.08449487
# Run: 9, iteration: 9/20, moves: 123, ncost: 112971862.81027442
# Run: 9, iteration: 10/20, moves: 91, ncost: 112439362.38597241
# Run: 9, iteration: 11/20, moves: 72, ncost: 112119353.75608878
# Run: 9, iteration: 12/20, moves: 54, ncost: 111931602.87724447
# Run: 9, iteration: 13/20, moves: 39, ncost: 111830222.35742708
# Run: 9, iteration: 14/20, moves: 28, ncost: 111769498.01124991
# Run: 9, iteration: 15/20, moves: 22, ncost: 111734978.74761589
# Run: 9, iteration: 16/20, moves: 15, ncost: 111715465.66720398
# Run: 9, iteration: 17/20, moves: 14, ncost: 111701972.26551999
# Run: 9, iteration: 18/20, moves: 10, ncost: 111693424.42476787
# Run: 9, iteration: 19/20, moves: 7, ncost: 111688665.35406046
# Run: 9, iteration: 20/20, moves: 6, ncost: 111684987.03515302
# Run: 9, iteration: 21/20, moves: 4, ncost: 111683050.07982837
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/20, moves: 695, ncost: 168077747.95368677
# Run: 10, iteration: 2/20, moves: 336, ncost: 153070478.18610358
# Run: 10, iteration: 3/20, moves: 214, ncost: 144054835.450632
# Run: 10, iteration: 4/20, moves: 183, ncost: 137834467.6173362
# Run: 10, iteration: 5/20, moves: 161, ncost: 133115659.94517845
# Run: 10, iteration: 6/20, moves: 144, ncost: 129372865.5487855
# Run: 10, iteration: 7/20, moves: 129, ncost: 126358854.62477271
# Run: 10, iteration: 8/20, moves: 116, ncost: 123896619.802107
# Run: 10, iteration: 9/20, moves: 106, ncost: 121850031.68823811
# Run: 10, iteration: 10/20, moves: 98, ncost: 120123330.16976124
# Run: 10, iteration: 11/20, moves: 88, ncost: 118701935.00654532
# Run: 10, iteration: 12/20, moves: 78, ncost: 117556390.64697686
# Run: 10, iteration: 13/20, moves: 74, ncost: 116565477.28684129
# Run: 10, iteration: 14/20, moves: 67, ncost: 115748774.6588646
# Run: 10, iteration: 15/20, moves: 59, ncost: 115087575.50551724
# Run: 10, iteration: 16/20, moves: 55, ncost: 114533667.60240906
# Run: 10, iteration: 17/20, moves: 50, ncost: 114066720.50335068
# Run: 10, iteration: 18/20, moves: 47, ncost: 113669503.14708756
# Run: 10, iteration: 19/20, moves: 41, ncost: 113352310.2696643
# Run: 10, iteration: 20/20, moves: 38, ncost: 113084251.33991727
# Run: 10, iteration: 21/20, moves: 37, ncost: 112842716.61940524
# Best run was number 1

# %%
print(kproto.cluster_centroids_)
# Out:
# [array([[ 2.72200000e+03,  1.02321725e+00,  8.65091211e+00,
#          2.05183852e+01, -9.81920894e+01,  2.98507463e-02],
#        [ 2.11900000e+03,  1.02653400e+00,  1.24170813e+01,
#          2.04918528e+01, -9.81958875e+01,  9.83416252e-01],
#        [ 1.51500000e+03,  1.02809917e+00,  1.08966942e+01,
#          2.05104161e+01, -9.81914567e+01,  1.98016529e+00],
#        [ 3.03500000e+02,  1.40264026e+00,  2.02164466e+01,
#          2.05031286e+01, -9.81923986e+01,  4.00990099e+00],
#        [ 9.09500000e+02,  1.05775578e+00,  1.69818482e+01,
#          2.05120199e+01, -9.81918722e+01,  4.95049505e+00],
#        [ 3.32450000e+03,  1.04318937e+00,  9.95985604e+00,
#          2.05162271e+01, -9.81751484e+01,  3.00000000e+00]]), array([['A1'],
#        ['A1'],
#        ['A1'],
#        ['A1'],
#        ['A1'],
#        ['A1']], dtype='<U2')]

# %%
cluster_dict=[]
for c in clusters:
    cluster_dict.append(c)

# %%
cluster_dict
plt.plot(cluster_dict)

# %%
brewing_df['cluster']=cluster_dict

# %%
brewing_df
# Out:
#       Id_Cliente id_Agencia  Frecuencia  Vol_Entrega        lat        lon  \
# 0              1         A1           1          2.0  20.506052 -98.212377
# 1              2         A1           1         17.0  20.458128 -98.221248
# 2              3         A1           1          2.0  20.530427 -98.236860
# 3              4         A1           3         15.0  20.488655 -98.202940
# 4              5         A1           1          2.0  20.533253 -98.219669
# ...          ...        ...         ...          ...        ...        ...
# 3620        3621         A1           1         15.0  20.558651 -98.149706
# 3621        3622         A1           1          2.0  20.541300 -98.157300
# 3622        3623         A1           1          6.0  20.509200 -98.128000
# 3623        3624         A1           1         31.0  20.513400 -98.154500
# 3624        3625         A1           2         18.5  20.521772 -98.166209
#
#       cluster
# 0           4
# 1           4
# 2           4
# 3           4
# 4           4
# ...       ...
# 3620        3
# 3621        3
# 3622        3
# 3623        3
# 3624        3
#
# [3625 rows x 7 columns]

# %%
brewing_df.to_csv(r'C:\Users\usuario\Documents\Hackathon\dias_cliente.csv', index = False)

# %%
brewing_df[brewing_df['cluster']== 0].head(5)
# Out:
#       Id_Cliente id_Agencia  Frecuencia  Vol_Entrega        lat        lon  \
# 2410        2411         A1           1          4.0  20.482500 -98.175300
# 2411        2412         A1           1          2.0  20.459300 -98.166300
# 2412        2413         A1           1          2.0  20.514479 -98.264231
# 2413        2414         A1           1          4.0  20.482613 -98.176850
# 2414        2415         A1           1          4.0  20.491028 -98.139507
#
#       cluster
# 2410        0
# 2411        0
# 2412        0
# 2413        0
# 2414        0

# %%
brewing_df[brewing_df['cluster']== 1].head(5)
# Out:
#       Id_Cliente id_Agencia  Frecuencia  Vol_Entrega        lat        lon  \
# 1805        1806         A1           1         36.0  20.548845 -98.162240
# 1806        1807         A1           1          2.0  20.502945 -98.292845
# 1807        1808         A1           1        151.0  20.530504 -98.144063
# 1808        1809         A1           1          3.0  20.568191 -98.134477
# 1809        1810         A1           1          2.0  20.450515 -98.156608
#
#       cluster
# 1805        1
# 1806        1
# 1807        1
# 1808        1
# 1809        1

# %%
brewing_df[brewing_df['cluster']== 2].head(5)
# Out:
#       Id_Cliente id_Agencia  Frecuencia  Vol_Entrega        lat        lon  \
# 1202        1203         A1           1          7.0  20.563681 -98.127788
# 1203        1204         A1           1          1.0  20.469800 -98.179807
# 1204        1205         A1           1          2.0  20.544422 -98.213662
# 1205        1206         A1           1          5.0  20.559964 -98.208432
# 1206        1207         A1           1          1.0  20.559988 -98.138488
#
#       cluster
# 1202        2
# 1203        2
# 1204        2
# 1205        2
# 1206        2

# %%
brewing_df[brewing_df['cluster']== 3].head(5)
# Out:
#       Id_Cliente id_Agencia  Frecuencia  Vol_Entrega        lat        lon  \
# 3017        3018         A1           1          7.0  20.557345 -98.178479
# 3018        3019         A1           1         10.0  20.542800 -98.142900
# 3019        3020         A1           1          1.0  20.507537 -98.261705
# 3020        3021         A1           1          2.0  20.458100 -98.280000
# 3021        3022         A1           1          5.0  20.511885 -98.224175
#
#       cluster
# 3017        3
# 3018        3
# 3019        3
# 3020        3
# 3021        3

# %%
brewing_df[brewing_df['cluster']== 4].head(5)
# Out:
#    Id_Cliente id_Agencia  Frecuencia  Vol_Entrega        lat        lon  \
# 0           1         A1           1          2.0  20.506052 -98.212377
# 1           2         A1           1         17.0  20.458128 -98.221248
# 2           3         A1           1          2.0  20.530427 -98.236860
# 3           4         A1           3         15.0  20.488655 -98.202940
# 4           5         A1           1          2.0  20.533253 -98.219669
#
#    cluster
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
brewing_df[brewing_df['cluster']== 5].head(5)
# Out:
#      Id_Cliente id_Agencia  Frecuencia  Vol_Entrega        lat        lon  \
# 600         601         A1           1          2.0  20.471726 -98.232468
# 601         602         A1           1         26.0  20.500801 -98.181245
# 602         603         A1           1         15.0  20.546942 -98.139555
# 603         604         A1           1          4.0  20.522021 -98.228825
# 604         605         A1           1          2.0  20.445876 -98.173739
#
#      cluster
# 600        5
# 601        5
# 602        5
# 603        5
# 604        5

# %%
brewing_df_solo_cluster = brewing_df.drop(['id_Agencia','Frecuencia','Vol_Entrega','lat','lon'], axis=1)
brewing_df_solo_cluster
# Out:
#       Id_Cliente  cluster
# 0              1        4
# 1              2        4
# 2              3        4
# 3              4        4
# 4              5        4
# ...          ...      ...
# 3620        3621        3
# 3621        3622        3
# 3622        3623        3
# 3623        3624        3
# 3624        3625        3
#
# [3625 rows x 2 columns]

# %%
brewing_df_solo_cluster
# Out:
#       Id_Cliente  cluster
# 0              1        4
# 1              2        4
# 2              3        4
# 3              4        4
# 4              5        4
# ...          ...      ...
# 3620        3621        3
# 3621        3622        3
# 3622        3623        3
# 3623        3624        3
# 3624        3625        3
#
# [3625 rows x 2 columns]
