# %% [markdown]
# # Polynomial Regression (Ricardo & Carlos)

# %% [markdown]
# What if your data doesn't look linear at all? Let's look at some more realistic-looking page speed / purchase data:

# %%
# %matplotlib inline
from pylab import *
import numpy as np

np.random.seed(2)
pageSpeeds = np.random.normal(3.0, 1.0, 1000)
purchaseAmount = np.random.normal(50.0, 10.0, 1000) / pageSpeeds

scatter(pageSpeeds, purchaseAmount)

# %% [markdown]
# numpy has a handy polyfit function we can use, to let us construct an nth-degree polynomial model of our data that minimizes squared error. Let's try it with a 4th degree polynomial:

# %%
x = np.array(pageSpeeds)
y = np.array(purchaseAmount)

p4 = np.poly1d(np.polyfit(x, y, 4))

# %% [markdown]
# We'll visualize our original scatter plot, together with a plot of our predicted values using the polynomial for page speed times ranging from 0-7 seconds:

# %%
import matplotlib.pyplot as plt

xp = np.linspace(0, 7, 100)
plt.scatter(x, y)
plt.plot(xp, p4(xp), c='r')
plt.show()

# %% [markdown]
# Looks pretty good! Let's measure the r-squared error:

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y, p4(x))

print(r2)
# Out:
# 0.82937663963

# %% [markdown]
# ## Activity

# %% [markdown]
# Try different polynomial orders. Can you get a better fit with higher orders? Do you start to see overfitting, even though the r-squared score looks good for this particular data set?

# %%
#import the libraries an functions
# %matplotlib inline
from pylab import *
import numpy as np
#create randoms data, with seed reset (2 time), the same set of numbers will appear every time.
np.random.seed(2)
#save in pageSpeeds the next information: the media, standard desviation and the number samples
pageSpeeds = np.random.normal(3.0, 1.0, 1000)
#save in purchaseAmount the next information: the media, standard desviation 
#and the number samples and list was divited by pageSpeeds
purchaseAmount = np.random.normal(50.0, 10.0, 1000) / pageSpeeds
#plot the pageSpeeds, purchaseAmount like x and y respectly
scatter(pageSpeeds, purchaseAmount)
# we use lineal regression to earn a polynom of grade 1, import the function stats by scipy
# also we do slope, intercept, r_value, p_value and std_err in the linela regress of 
# pageSpeeds and purchaseAmount
from scipy import stats

slope, intercept, r_value, p_value, std_err = stats.linregress(pageSpeeds, purchaseAmount)

def predict(x):
# we relize Equation of a Straight Line
    return slope * x + intercept
# we relize Equation of a Straight Line with pageSpeeds and save it in p1
p1 = predict(pageSpeeds)
#earn the r value ^2
r_value ** 2
# plot a scatter of pageSpeeds and purchaseAmount
plt.scatter(pageSpeeds, purchaseAmount)
# plot a red straight Line in p1
plt.plot(pageSpeeds, p1, c='r')
# show the final plot
plt.show()
#2 we use a polynom of grade 2 to earn a r value close to 1
# creat an array in X and y with pageSpeeds and purchaseAmount respectly
x = np.array(pageSpeeds)
y = np.array(purchaseAmount)
# we do a polynomial regress of grade 2
p2 = np.poly1d(np.polyfit(x, y, 2))

import matplotlib.pyplot as plt
# Return evenly spaced numbers over a specified interval. from 0 to 7 
# Returns 100 evenly spaced samples
xp = np.linspace(0, 7, 100)
plt.scatter(x, y)
# plot a red polynomial line in p2
plt.plot(xp, p2(xp), c='r')
# show the plot
plt.show()

from sklearn.metrics import r2_score
# in P2r2 save r_value^2
P2r2 = r2_score(y, p2(x))
# show r_value^2
print(P2r2)
#3 we use a polynom of grade 3 to earn a r value close to 1
# the process is the same of 2 polynomial regress but whit grade 3
x = np.array(pageSpeeds)
y = np.array(purchaseAmount)

p3 = np.poly1d(np.polyfit(x, y, 3))

import matplotlib.pyplot as plt

xp = np.linspace(0, 7, 100)
plt.scatter(x, y)
plt.plot(xp, p3(xp), c='r')
plt.show()

from sklearn.metrics import r2_score

P3r2 = r2_score(y, p3(x))

print(P3r2)

#4 #we use a polynom of grade 4 to earn a r value close to 1
# the process is the same of 2 polynomial regress but whit grade 4
x = np.array(pageSpeeds)
y = np.array(purchaseAmount)

p4 = np.poly1d(np.polyfit(x, y, 4))

import matplotlib.pyplot as plt

xp = np.linspace(0, 7, 100)
plt.scatter(x, y)
plt.plot(xp, p4(xp), c='r')
plt.show()

from sklearn.metrics import r2_score

P4r2 = r2_score(y, p4(x))

print(P4r2)

#5 we use a polynom of grade 5 to earn a r value close to 1
# the process is the same of 2 polynomial regress but whit grade 5
x = np.array(pageSpeeds)
y = np.array(purchaseAmount)

p5 = np.poly1d(np.polyfit(x, y, 5))

import matplotlib.pyplot as plt

xp = np.linspace(0, 7, 100)
plt.scatter(x, y)
plt.plot(xp, p5(xp), c='r')
plt.show()

from sklearn.metrics import r2_score

P5r2 = r2_score(y, p5(x))

print(P5r2)

#6 we use a polynom of grade 6 to earn a r value close to 1
# the process is the same of 2 polynomial regress but whit grade 6
x = np.array(pageSpeeds)
y = np.array(purchaseAmount)

p6 = np.poly1d(np.polyfit(x, y, 6))

import matplotlib.pyplot as plt

xp = np.linspace(0, 7, 100)
plt.scatter(x, y)
plt.plot(xp, p6(xp), c='r')
plt.show()

from sklearn.metrics import r2_score

P6r2 = r2_score(y, p6(x))

print(P6r2)

#7 we use a polynom of grade 7 to earn a r value close to 1
# the process is the same of 2 polynomial regress but whit grade 7
x = np.array(pageSpeeds)
y = np.array(purchaseAmount)

p7 = np.poly1d(np.polyfit(x, y, 7))

import matplotlib.pyplot as plt

xp = np.linspace(0, 7, 100)
plt.scatter(x, y)
plt.plot(xp, p7(xp), c='r')
plt.show()

from sklearn.metrics import r2_score

P7r2 = r2_score(y, p7(x))

print(P7r2)

#8 we use a polynom of grade 8 to earn a r value close to 1
# the process is the same of 2 polynomial regress but whit grade 8
x = np.array(pageSpeeds)
y = np.array(purchaseAmount)

p8 = np.poly1d(np.polyfit(x, y, 8))

import matplotlib.pyplot as plt

xp = np.linspace(0, 7, 100)
plt.scatter(x, y)
plt.plot(xp, p8(xp), c='r')
plt.show()

from sklearn.metrics import r2_score

P8r2 = r2_score(y, p8(x))

print(P8r2)

#9 we use a polynom of grade 9 to earn a r value close to 1
# the process is the same of 2 polynomial regress but whit grade 9
# also we can see static r value which show the disadvantage for this function
x = np.array(pageSpeeds)
y = np.array(purchaseAmount)

p9 = np.poly1d(np.polyfit(x, y, 9))

import matplotlib.pyplot as plt

xp = np.linspace(0, 7, 100)
plt.scatter(x, y)
plt.plot(xp, p9(xp), c='r')
plt.show()

from sklearn.metrics import r2_score

P9r2 = r2_score(y, p9(x))

print(P9r2)

#10 we use a polynom of grade 2 to earn a r value close to 1
# the process is the same of 2 polynomial regress but whit grade 10
x = np.array(pageSpeeds)
y = np.array(purchaseAmount)

p10 = np.poly1d(np.polyfit(x, y, 10))

import matplotlib.pyplot as plt

xp = np.linspace(0, 7, 100)
plt.scatter(x, y)
plt.plot(xp, p10(xp), c='r')
plt.show()

from sklearn.metrics import r2_score

P10r2 = r2_score(y, p10(x))

print(P10r2)
# Out:
# 0.692744635054
# 0.784235403082
# 0.82937663963
# 0.855388438619
# 0.870073399987
# 0.877836978171
# 0.881439566368
# 0.883026325662
# 0.883217235626
